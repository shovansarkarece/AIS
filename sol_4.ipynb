# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

# %%
class_list = model.names 
class_list
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Open the video file
cap = cv2.VideoCapture('test_videos/4.mp4')

# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

class_list = model.names 
#class_list

# Open the video file
cap = cv2.VideoCapture('test_videos/4.mp4')

line_y_red = 430  # Red line position

# Dictionary to store object counts by class
class_counts = defaultdict(int)

# Dictionary to keep track of object IDs that have crossed the line
crossed_ids = set()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes = [1,2,3,5,6,7]) 
    #print(results)

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (690, line_y_red), (1130, line_y_red), (0, 0, 255), 3)
        #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


        

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2            

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 


            # Check if the object has crossed the red line
            if cy > line_y_red and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1


        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    
    
    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)    
    
    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 836.3ms
# Speed: 2.5ms preprocess, 836.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 937.3ms
# Speed: 3.0ms preprocess, 937.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 954.9ms
# Speed: 2.0ms preprocess, 954.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 914.3ms
# Speed: 2.0ms preprocess, 914.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 838.2ms
# Speed: 4.0ms preprocess, 838.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 883.3ms
# Speed: 3.5ms preprocess, 883.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 876.7ms
# Speed: 3.0ms preprocess, 876.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 823.9ms
# Speed: 4.0ms preprocess, 823.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 motorcycles, 3 buss, 2 trucks, 881.7ms
# Speed: 3.0ms preprocess, 881.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 850.2ms
# Speed: 2.0ms preprocess, 850.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 4 motorcycles, 3 buss, 1 truck, 858.3ms
# Speed: 3.5ms preprocess, 858.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 2 trucks, 934.1ms
# Speed: 3.5ms preprocess, 934.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 951.0ms
# Speed: 3.0ms preprocess, 951.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 927.6ms
# Speed: 4.0ms preprocess, 927.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 956.2ms
# Speed: 5.0ms preprocess, 956.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 1068.6ms
# Speed: 3.0ms preprocess, 1068.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 1073.3ms
# Speed: 2.6ms preprocess, 1073.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 1109.1ms
# Speed: 3.0ms preprocess, 1109.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 1034.1ms
# Speed: 3.0ms preprocess, 1034.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 1055.2ms
# Speed: 5.6ms preprocess, 1055.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 1045.7ms
# Speed: 2.5ms preprocess, 1045.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 1025.6ms
# Speed: 2.0ms preprocess, 1025.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 1024.2ms
# Speed: 3.0ms preprocess, 1024.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 1027.0ms
# Speed: 2.6ms preprocess, 1027.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 987.6ms
# Speed: 4.0ms preprocess, 987.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 961.8ms
# Speed: 3.0ms preprocess, 961.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 992.0ms
# Speed: 3.9ms preprocess, 992.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 984.5ms
# Speed: 4.5ms preprocess, 984.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 906.1ms
# Speed: 2.5ms preprocess, 906.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 889.6ms
# Speed: 2.0ms preprocess, 889.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 906.2ms
# Speed: 3.9ms preprocess, 906.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 850.9ms
# Speed: 2.1ms preprocess, 850.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 799.6ms
# Speed: 2.0ms preprocess, 799.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 817.2ms
# Speed: 2.0ms preprocess, 817.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 913.0ms
# Speed: 2.0ms preprocess, 913.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 909.0ms
# Speed: 2.0ms preprocess, 909.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 motorcycles, 3 buss, 934.5ms
# Speed: 2.0ms preprocess, 934.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 motorcycles, 3 buss, 824.9ms
# Speed: 4.0ms preprocess, 824.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 motorcycles, 4 buss, 927.2ms
# Speed: 2.2ms preprocess, 927.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 4 buss, 956.0ms
# Speed: 3.4ms preprocess, 956.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 958.1ms
# Speed: 2.4ms preprocess, 958.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 838.2ms
# Speed: 5.6ms preprocess, 838.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 913.2ms
# Speed: 3.0ms preprocess, 913.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 1012.5ms
# Speed: 3.0ms preprocess, 1012.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 1009.5ms
# Speed: 3.6ms preprocess, 1009.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 1050.2ms
# Speed: 4.0ms preprocess, 1050.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 1039.3ms
# Speed: 4.0ms preprocess, 1039.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 1021.2ms
# Speed: 7.9ms preprocess, 1021.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 966.0ms
# Speed: 3.0ms preprocess, 966.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 4 buss, 997.9ms
# Speed: 5.0ms preprocess, 997.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 3 buss, 912.0ms
# Speed: 2.0ms preprocess, 912.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 935.8ms
# Speed: 2.0ms preprocess, 935.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 948.5ms
# Speed: 2.0ms preprocess, 948.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 923.0ms
# Speed: 5.0ms preprocess, 923.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 902.2ms
# Speed: 2.0ms preprocess, 902.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 2 buss, 888.5ms
# Speed: 2.4ms preprocess, 888.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 858.6ms
# Speed: 3.0ms preprocess, 858.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 889.3ms
# Speed: 3.0ms preprocess, 889.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 841.1ms
# Speed: 2.5ms preprocess, 841.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 1 truck, 829.8ms
# Speed: 2.8ms preprocess, 829.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 964.6ms
# Speed: 3.5ms preprocess, 964.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 1 truck, 927.9ms
# Speed: 5.0ms preprocess, 927.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 1 truck, 842.7ms
# Speed: 4.3ms preprocess, 842.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 935.5ms
# Speed: 3.1ms preprocess, 935.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 861.6ms
# Speed: 3.6ms preprocess, 861.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 2 buss, 941.9ms
# Speed: 2.0ms preprocess, 941.9ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 950.7ms
# Speed: 2.2ms preprocess, 950.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 970.1ms
# Speed: 2.8ms preprocess, 970.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 942.5ms
# Speed: 3.0ms preprocess, 942.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 979.6ms
# Speed: 3.0ms preprocess, 979.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 977.2ms
# Speed: 4.0ms preprocess, 977.2ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 1 bus, 1 truck, 1085.7ms
# Speed: 3.5ms preprocess, 1085.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 2 buss, 1040.0ms
# Speed: 4.3ms preprocess, 1040.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 2 buss, 1 truck, 1091.3ms
# Speed: 4.1ms preprocess, 1091.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 2 buss, 1 truck, 1024.0ms
# Speed: 5.1ms preprocess, 1024.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 motorcycles, 2 buss, 883.8ms
# Speed: 3.0ms preprocess, 883.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 2 buss, 1041.8ms
# Speed: 3.4ms preprocess, 1041.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 1011.4ms
# Speed: 2.0ms preprocess, 1011.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 956.1ms
# Speed: 2.5ms preprocess, 956.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 910.3ms
# Speed: 3.6ms preprocess, 910.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 946.1ms
# Speed: 3.0ms preprocess, 946.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 918.0ms
# Speed: 3.0ms preprocess, 918.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 1010.6ms
# Speed: 3.0ms preprocess, 1010.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 1102.2ms
# Speed: 5.0ms preprocess, 1102.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 3 buss, 1 truck, 1121.9ms
# Speed: 4.0ms preprocess, 1121.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 1 truck, 1075.2ms
# Speed: 3.5ms preprocess, 1075.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 1087.8ms
# Speed: 2.5ms preprocess, 1087.8ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 1 truck, 1099.0ms
# Speed: 4.0ms preprocess, 1099.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 1217.6ms
# Speed: 3.0ms preprocess, 1217.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 3 buss, 1 truck, 1271.8ms
# Speed: 3.0ms preprocess, 1271.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 3 buss, 1 truck, 1179.9ms
# Speed: 2.0ms preprocess, 1179.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 1063.0ms
# Speed: 2.2ms preprocess, 1063.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1119.1ms
# Speed: 2.0ms preprocess, 1119.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1235.0ms
# Speed: 1.8ms preprocess, 1235.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1183.4ms
# Speed: 2.0ms preprocess, 1183.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1185.8ms
# Speed: 2.0ms preprocess, 1185.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1207.9ms
# Speed: 4.1ms preprocess, 1207.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1087.7ms
# Speed: 2.0ms preprocess, 1087.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1074.9ms
# Speed: 3.0ms preprocess, 1074.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1117.3ms
# Speed: 4.3ms preprocess, 1117.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 1144.7ms
# Speed: 2.0ms preprocess, 1144.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
