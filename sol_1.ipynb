# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

# %%
class_list = model.names 
class_list
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Open the video file
cap = cv2.VideoCapture('test_videos/1.mp4')

# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('yolo11l.pt')

class_list = model.names 
#class_list

# Open the video file
cap = cv2.VideoCapture('test_videos/1.mp4')

line_y_red = 430  # Red line position

# Dictionary to store object counts by class
class_counts = defaultdict(int)

# Dictionary to keep track of object IDs that have crossed the line
crossed_ids = set()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes = [1,2,3,5,6,7]) 
    #print(results)

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (1190, line_y_red), (1130, line_y_red), (0, 0, 255), 3)
        #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


        

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2            

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 


            # Check if the object has crossed the red line
            if cy > line_y_red and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1


        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    
    
    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)    
    
    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 15 cars, 2 trucks, 573.1ms
# Speed: 5.0ms preprocess, 573.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 545.9ms
# Speed: 2.0ms preprocess, 545.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 541.2ms
# Speed: 2.0ms preprocess, 541.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 426.3ms
# Speed: 2.0ms preprocess, 426.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 428.7ms
# Speed: 2.0ms preprocess, 428.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 419.5ms
# Speed: 2.0ms preprocess, 419.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 446.2ms
# Speed: 2.0ms preprocess, 446.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 425.8ms
# Speed: 1.0ms preprocess, 425.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 423.8ms
# Speed: 1.0ms preprocess, 423.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 430.8ms
# Speed: 1.0ms preprocess, 430.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 431.3ms
# Speed: 1.0ms preprocess, 431.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 431.8ms
# Speed: 2.0ms preprocess, 431.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 429.7ms
# Speed: 2.0ms preprocess, 429.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 436.8ms
# Speed: 2.0ms preprocess, 436.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 463.5ms
# Speed: 2.0ms preprocess, 463.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 443.4ms
# Speed: 1.0ms preprocess, 443.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 454.8ms
# Speed: 2.0ms preprocess, 454.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 4 trucks, 428.8ms
# Speed: 1.0ms preprocess, 428.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 418.8ms
# Speed: 2.0ms preprocess, 418.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 425.8ms
# Speed: 2.0ms preprocess, 425.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 420.8ms
# Speed: 2.0ms preprocess, 420.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 448.3ms
# Speed: 2.0ms preprocess, 448.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 429.2ms
# Speed: 2.0ms preprocess, 429.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 429.4ms
# Speed: 2.0ms preprocess, 429.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 432.8ms
# Speed: 2.0ms preprocess, 432.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 420.4ms
# Speed: 1.0ms preprocess, 420.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 447.9ms
# Speed: 2.0ms preprocess, 447.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 418.8ms
# Speed: 2.0ms preprocess, 418.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 450.8ms
# Speed: 3.0ms preprocess, 450.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 494.5ms
# Speed: 2.0ms preprocess, 494.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 461.1ms
# Speed: 2.0ms preprocess, 461.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 436.3ms
# Speed: 2.0ms preprocess, 436.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 429.3ms
# Speed: 2.0ms preprocess, 429.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 439.8ms
# Speed: 2.0ms preprocess, 439.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 435.4ms
# Speed: 2.0ms preprocess, 435.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 443.7ms
# Speed: 2.0ms preprocess, 443.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 438.8ms
# Speed: 2.0ms preprocess, 438.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 436.3ms
# Speed: 1.5ms preprocess, 436.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 437.3ms
# Speed: 2.0ms preprocess, 437.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 434.3ms
# Speed: 1.0ms preprocess, 434.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 447.3ms
# Speed: 2.0ms preprocess, 447.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 437.8ms
# Speed: 2.0ms preprocess, 437.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 438.8ms
# Speed: 2.0ms preprocess, 438.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 444.3ms
# Speed: 1.0ms preprocess, 444.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 442.1ms
# Speed: 1.0ms preprocess, 442.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 442.4ms
# Speed: 2.0ms preprocess, 442.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 431.8ms
# Speed: 1.0ms preprocess, 431.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 466.0ms
# Speed: 2.0ms preprocess, 466.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 433.3ms
# Speed: 2.0ms preprocess, 433.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 433.3ms
# Speed: 2.0ms preprocess, 433.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 436.9ms
# Speed: 2.0ms preprocess, 436.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 444.6ms
# Speed: 2.0ms preprocess, 444.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 425.7ms
# Speed: 1.0ms preprocess, 425.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 451.8ms
# Speed: 2.0ms preprocess, 451.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 448.6ms
# Speed: 2.1ms preprocess, 448.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 441.1ms
# Speed: 2.0ms preprocess, 441.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 434.8ms
# Speed: 1.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 449.9ms
# Speed: 2.0ms preprocess, 449.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 434.8ms
# Speed: 1.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 432.8ms
# Speed: 2.0ms preprocess, 432.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 435.2ms
# Speed: 1.0ms preprocess, 435.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 433.8ms
# Speed: 4.0ms preprocess, 433.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 449.2ms
# Speed: 1.0ms preprocess, 449.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 430.0ms
# Speed: 2.0ms preprocess, 430.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 455.6ms
# Speed: 1.0ms preprocess, 455.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 463.3ms
# Speed: 2.0ms preprocess, 463.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 438.7ms
# Speed: 2.0ms preprocess, 438.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 452.8ms
# Speed: 1.0ms preprocess, 452.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 430.4ms
# Speed: 2.0ms preprocess, 430.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 437.3ms
# Speed: 2.0ms preprocess, 437.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 434.8ms
# Speed: 2.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 441.7ms
# Speed: 2.0ms preprocess, 441.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 438.4ms
# Speed: 2.0ms preprocess, 438.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 441.4ms
# Speed: 1.0ms preprocess, 441.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 441.0ms
# Speed: 2.0ms preprocess, 441.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 446.3ms
# Speed: 1.0ms preprocess, 446.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 444.5ms
# Speed: 2.0ms preprocess, 444.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 484.5ms
# Speed: 2.0ms preprocess, 484.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 450.7ms
# Speed: 2.0ms preprocess, 450.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 451.3ms
# Speed: 2.0ms preprocess, 451.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 434.8ms
# Speed: 2.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 458.1ms
# Speed: 2.0ms preprocess, 458.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 451.6ms
# Speed: 2.0ms preprocess, 451.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 438.9ms
# Speed: 1.0ms preprocess, 438.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 436.2ms
# Speed: 2.0ms preprocess, 436.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3 trucks, 446.3ms
# Speed: 2.0ms preprocess, 446.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 456.6ms
# Speed: 2.0ms preprocess, 456.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 433.4ms
# Speed: 2.0ms preprocess, 433.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 446.3ms
# Speed: 1.0ms preprocess, 446.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 438.0ms
# Speed: 2.0ms preprocess, 438.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 457.3ms
# Speed: 2.0ms preprocess, 457.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 434.2ms
# Speed: 2.0ms preprocess, 434.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 440.9ms
# Speed: 2.0ms preprocess, 440.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 437.4ms
# Speed: 2.0ms preprocess, 437.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 436.3ms
# Speed: 1.0ms preprocess, 436.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 455.5ms
# Speed: 2.0ms preprocess, 455.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 438.2ms
# Speed: 2.0ms preprocess, 438.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 439.7ms
# Speed: 2.0ms preprocess, 439.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 446.6ms
# Speed: 2.0ms preprocess, 446.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 438.5ms
# Speed: 1.9ms preprocess, 438.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 436.5ms
# Speed: 2.0ms preprocess, 436.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 443.7ms
# Speed: 2.0ms preprocess, 443.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 435.5ms
# Speed: 2.0ms preprocess, 435.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 438.3ms
# Speed: 2.0ms preprocess, 438.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 439.2ms
# Speed: 2.0ms preprocess, 439.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 428.4ms
# Speed: 3.0ms preprocess, 428.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 458.1ms
# Speed: 2.0ms preprocess, 458.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 434.9ms
# Speed: 2.0ms preprocess, 434.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 434.5ms
# Speed: 1.0ms preprocess, 434.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 436.0ms
# Speed: 2.0ms preprocess, 436.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 465.3ms
# Speed: 2.0ms preprocess, 465.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 443.3ms
# Speed: 1.0ms preprocess, 443.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 444.0ms
# Speed: 2.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 459.8ms
# Speed: 2.0ms preprocess, 459.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 437.4ms
# Speed: 1.0ms preprocess, 437.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 451.5ms
# Speed: 2.0ms preprocess, 451.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 442.4ms
# Speed: 2.0ms preprocess, 442.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 443.6ms
# Speed: 1.0ms preprocess, 443.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 446.9ms
# Speed: 2.0ms preprocess, 446.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 464.4ms
# Speed: 1.0ms preprocess, 464.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 443.9ms
# Speed: 2.0ms preprocess, 443.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 450.6ms
# Speed: 2.0ms preprocess, 450.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 434.8ms
# Speed: 1.0ms preprocess, 434.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 444.8ms
# Speed: 3.0ms preprocess, 444.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 443.5ms
# Speed: 2.0ms preprocess, 443.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 431.6ms
# Speed: 2.0ms preprocess, 431.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 440.4ms
# Speed: 1.0ms preprocess, 440.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 433.1ms
# Speed: 2.0ms preprocess, 433.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 432.9ms
# Speed: 2.0ms preprocess, 432.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 440.1ms
# Speed: 2.0ms preprocess, 440.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 444.4ms
# Speed: 2.0ms preprocess, 444.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 452.8ms
# Speed: 2.0ms preprocess, 452.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 439.8ms
# Speed: 1.0ms preprocess, 439.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 433.3ms
# Speed: 1.0ms preprocess, 433.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 429.7ms
# Speed: 2.0ms preprocess, 429.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 445.1ms
# Speed: 2.0ms preprocess, 445.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 466.2ms
# Speed: 2.0ms preprocess, 466.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 459.7ms
# Speed: 2.0ms preprocess, 459.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 439.5ms
# Speed: 2.0ms preprocess, 439.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 444.1ms
# Speed: 2.0ms preprocess, 444.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 456.9ms
# Speed: 2.0ms preprocess, 456.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 453.3ms
# Speed: 2.0ms preprocess, 453.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 436.6ms
# Speed: 2.0ms preprocess, 436.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 454.1ms
# Speed: 2.0ms preprocess, 454.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 457.8ms
# Speed: 2.0ms preprocess, 457.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 442.8ms
# Speed: 1.0ms preprocess, 442.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 438.8ms
# Speed: 2.0ms preprocess, 438.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 459.4ms
# Speed: 2.0ms preprocess, 459.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 432.4ms
# Speed: 2.0ms preprocess, 432.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 434.3ms
# Speed: 2.0ms preprocess, 434.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 457.8ms
# Speed: 2.0ms preprocess, 457.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 465.8ms
# Speed: 4.0ms preprocess, 465.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 438.3ms
# Speed: 2.0ms preprocess, 438.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 439.0ms
# Speed: 1.9ms preprocess, 439.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 434.5ms
# Speed: 2.0ms preprocess, 434.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 450.3ms
# Speed: 2.0ms preprocess, 450.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 438.0ms
# Speed: 1.0ms preprocess, 438.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 430.6ms
# Speed: 2.0ms preprocess, 430.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 440.6ms
# Speed: 1.5ms preprocess, 440.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 448.3ms
# Speed: 1.0ms preprocess, 448.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 447.9ms
# Speed: 1.0ms preprocess, 447.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 468.3ms
# Speed: 1.0ms preprocess, 468.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
